# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
import time
import importlib
# %matplotlib inline

#from util.data_utils import get_CIFAR10_data_indiv
#from util.data_utils import abcd
#from util.running import run_model
from util.data_utils import get_CIFAR10_data_indiv
import util.running as run
import model.residual as reg
import model.nin as nin
import model.inception as incept
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test= get_CIFAR10_data_indiv()
data = (X_train, y_train, X_val, y_val, X_test, y_test)

# %%
# Test Complete
run.cifar_10_running(incept.ver1,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 21.8 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 2.04 and accuracy of 0.27
# Iteration 200: with minibatch training loss = 1.73 and accuracy of 0.47
# Iteration 300: with minibatch training loss = 1.72 and accuracy of 0.39
# Iteration 400: with minibatch training loss = 1.8 and accuracy of 0.36
# Iteration 500: with minibatch training loss = 1.85 and accuracy of 0.34
# Iteration 600: with minibatch training loss = 1.49 and accuracy of 0.52
# Iteration 700: with minibatch training loss = 1.45 and accuracy of 0.52
# Epoch 1, Overall loss = 2.78 and accuracy of 0.341
# Iteration 800: with minibatch training loss = 1.41 and accuracy of 0.55
# Iteration 900: with minibatch training loss = 1.58 and accuracy of 0.45
# Iteration 1000: with minibatch training loss = 1.54 and accuracy of 0.48
# Iteration 1100: with minibatch training loss = 1.66 and accuracy of 0.38
# ...

# %%
# Test Complete
run.cifar_10_running(incept.ver2,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 14.3 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 1.96 and accuracy of 0.23
# Iteration 200: with minibatch training loss = 1.78 and accuracy of 0.42
# Iteration 300: with minibatch training loss = 1.99 and accuracy of 0.36
# Iteration 400: with minibatch training loss = 1.67 and accuracy of 0.33
# Iteration 500: with minibatch training loss = 1.61 and accuracy of 0.42
# Iteration 600: with minibatch training loss = 1.74 and accuracy of 0.31
# Iteration 700: with minibatch training loss = 1.61 and accuracy of 0.39
# Epoch 1, Overall loss = 3.62 and accuracy of 0.351
# Iteration 800: with minibatch training loss = 1.73 and accuracy of 0.39
# Iteration 900: with minibatch training loss = 1.3 and accuracy of 0.56
# Iteration 1000: with minibatch training loss = 1.58 and accuracy of 0.48
# Iteration 1100: with minibatch training loss = 1.67 and accuracy of 0.45
# ...

# %%
# Test Complete
run.cifar_10_running(incept.ver3,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 25.4 and accuracy of 0.094
# Iteration 100: with minibatch training loss = 2.08 and accuracy of 0.28
# Iteration 200: with minibatch training loss = 1.68 and accuracy of 0.38
# Iteration 300: with minibatch training loss = 1.68 and accuracy of 0.38
# Iteration 400: with minibatch training loss = 1.59 and accuracy of 0.44
# Iteration 500: with minibatch training loss = 1.6 and accuracy of 0.41
# Iteration 600: with minibatch training loss = 1.53 and accuracy of 0.47
# Iteration 700: with minibatch training loss = 1.64 and accuracy of 0.39
# Epoch 1, Overall loss = 3.33 and accuracy of 0.349
# Iteration 800: with minibatch training loss = 1.67 and accuracy of 0.45
# Iteration 900: with minibatch training loss = 1.52 and accuracy of 0.44
# Iteration 1000: with minibatch training loss = 1.65 and accuracy of 0.42
# Iteration 1100: with minibatch training loss = 1.61 and accuracy of 0.42
# ...

# %%
# Test Imcomplete
run.cifar_10_running(incept.ver3_batch,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 3.25 and accuracy of 0.19
# Iteration 100: with minibatch training loss = 1.99 and accuracy of 0.28
# Iteration 200: with minibatch training loss = 1.69 and accuracy of 0.42
# Iteration 300: with minibatch training loss = 1.66 and accuracy of 0.44
# Iteration 400: with minibatch training loss = 1.75 and accuracy of 0.38
# Iteration 500: with minibatch training loss = 1.45 and accuracy of 0.42
# Iteration 600: with minibatch training loss = 1.58 and accuracy of 0.34
# Iteration 700: with minibatch training loss = 1.73 and accuracy of 0.38
# Epoch 1, Overall loss = 2.19 and accuracy of 0.399
# Iteration 800: with minibatch training loss = 1.6 and accuracy of 0.39
# Iteration 900: with minibatch training loss = 1.2 and accuracy of 0.53
# Iteration 1000: with minibatch training loss = 1.47 and accuracy of 0.48
# Iteration 1100: with minibatch training loss = 1.47 and accuracy of 0.38
# ...

# %%
# Test Complete
run.cifar_10_running(incept.ver4,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 26.8 and accuracy of 0.047
# Iteration 100: with minibatch training loss = 2.02 and accuracy of 0.27
# Iteration 200: with minibatch training loss = 1.82 and accuracy of 0.27
# Iteration 300: with minibatch training loss = 1.65 and accuracy of 0.44
# Iteration 400: with minibatch training loss = 1.7 and accuracy of 0.33
# Iteration 500: with minibatch training loss = 1.52 and accuracy of 0.41
# Iteration 600: with minibatch training loss = 1.54 and accuracy of 0.5
# Iteration 700: with minibatch training loss = 1.6 and accuracy of 0.41
# Epoch 1, Overall loss = 1.82 and accuracy of 0.337
# Iteration 800: with minibatch training loss = 1.49 and accuracy of 0.5
# Iteration 900: with minibatch training loss = 1.74 and accuracy of 0.34
# Iteration 1000: with minibatch training loss = 1.29 and accuracy of 0.58
# Iteration 1100: with minibatch training loss = 1.34 and accuracy of 0.52
# ...

# %%
# Test Imcomplete
run.cifar_10_running(incept.ver5,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 3.19 and accuracy of 0.11
# Iteration 100: with minibatch training loss = 1.96 and accuracy of 0.25
# Iteration 200: with minibatch training loss = 1.77 and accuracy of 0.38
# Iteration 300: with minibatch training loss = 1.64 and accuracy of 0.38
# Iteration 400: with minibatch training loss = 1.97 and accuracy of 0.28
# Iteration 500: with minibatch training loss = 1.6 and accuracy of 0.41
# Iteration 600: with minibatch training loss = 1.63 and accuracy of 0.39
# Iteration 700: with minibatch training loss = 1.63 and accuracy of 0.41
# Epoch 1, Overall loss = 1.79 and accuracy of 0.325
# Iteration 800: with minibatch training loss = 1.36 and accuracy of 0.56
# Iteration 900: with minibatch training loss = 1.42 and accuracy of 0.52
# Iteration 1000: with minibatch training loss = 1.29 and accuracy of 0.52
# Iteration 1100: with minibatch training loss = 1.38 and accuracy of 0.45
# ...

# %%
#  Test Complete
run.cifar_10_running(nin.ver1,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 11.4 and accuracy of 0.094
# Iteration 100: with minibatch training loss = 2.11 and accuracy of 0.25
# Iteration 200: with minibatch training loss = 1.98 and accuracy of 0.33
# Iteration 300: with minibatch training loss = 1.81 and accuracy of 0.31
# Iteration 400: with minibatch training loss = 1.95 and accuracy of 0.33
# Iteration 500: with minibatch training loss = 1.86 and accuracy of 0.3
# Iteration 600: with minibatch training loss = 1.98 and accuracy of 0.27
# Iteration 700: with minibatch training loss = 2.07 and accuracy of 0.38
# Epoch 1, Overall loss = 4.07 and accuracy of 0.257
# Iteration 800: with minibatch training loss = 2.04 and accuracy of 0.28
# Iteration 900: with minibatch training loss = 1.83 and accuracy of 0.38
# Iteration 1000: with minibatch training loss = 2.14 and accuracy of 0.22
# Iteration 1100: with minibatch training loss = 1.89 and accuracy of 0.34
# ...

# %%
#  Test Complete
run.cifar_10_running(nin.ver2,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 2.36 and accuracy of 0.094
# Iteration 100: with minibatch training loss = 1.99 and accuracy of 0.25
# Iteration 200: with minibatch training loss = 1.99 and accuracy of 0.2
# Iteration 300: with minibatch training loss = 2.15 and accuracy of 0.27
# Iteration 400: with minibatch training loss = 1.95 and accuracy of 0.28
# Iteration 500: with minibatch training loss = 1.93 and accuracy of 0.2
# Iteration 600: with minibatch training loss = 1.8 and accuracy of 0.27
# Iteration 700: with minibatch training loss = 1.79 and accuracy of 0.3
# Epoch 1, Overall loss = 1.99 and accuracy of 0.214
# Iteration 800: with minibatch training loss = 1.74 and accuracy of 0.25
# Iteration 900: with minibatch training loss = 1.86 and accuracy of 0.28
# Iteration 1000: with minibatch training loss = 1.8 and accuracy of 0.42
# Iteration 1100: with minibatch training loss = 1.68 and accuracy of 0.34
# ...

# %%
#  Test Complete
run.cifar_10_running(reg.ver1,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 75.1 and accuracy of 0.11
# Iteration 100: with minibatch training loss = 2.26 and accuracy of 0.094
# Iteration 200: with minibatch training loss = 2.33 and accuracy of 0.12
# Iteration 300: with minibatch training loss = 2.19 and accuracy of 0.17
# Iteration 400: with minibatch training loss = 2.17 and accuracy of 0.11
# Iteration 500: with minibatch training loss = 2.21 and accuracy of 0.078
# Iteration 600: with minibatch training loss = 2.08 and accuracy of 0.22
# Iteration 700: with minibatch training loss = 2.04 and accuracy of 0.2
# Epoch 1, Overall loss = 29.1 and accuracy of 0.179
# Iteration 800: with minibatch training loss = 2.07 and accuracy of 0.31
# Iteration 900: with minibatch training loss = 2.14 and accuracy of 0.25
# Iteration 1000: with minibatch training loss = 1.96 and accuracy of 0.31
# Iteration 1100: with minibatch training loss = 2.05 and accuracy of 0.25
# ...

# %%
#  Test Complete
run.cifar_10_running(reg.ver2,X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# Training
# Iteration 0: with minibatch training loss = 35.4 and accuracy of 0.094
# Iteration 100: with minibatch training loss = 2.09 and accuracy of 0.27
# Iteration 200: with minibatch training loss = 1.86 and accuracy of 0.23
# Iteration 300: with minibatch training loss = 1.86 and accuracy of 0.38
# Iteration 400: with minibatch training loss = 1.74 and accuracy of 0.36
# Iteration 500: with minibatch training loss = 1.61 and accuracy of 0.47
# Iteration 600: with minibatch training loss = 1.57 and accuracy of 0.41
# Iteration 700: with minibatch training loss = 1.42 and accuracy of 0.44
# Epoch 1, Overall loss = 1.87 and accuracy of 0.349
# Iteration 800: with minibatch training loss = 1.3 and accuracy of 0.52
# Iteration 900: with minibatch training loss = 1.34 and accuracy of 0.5
# Iteration 1000: with minibatch training loss = 1.21 and accuracy of 0.62
# Iteration 1100: with minibatch training loss = 1.5 and accuracy of 0.52
# ...
